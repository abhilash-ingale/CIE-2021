# %%
# Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gregori_up_1 = pd.read_csv("C:/Users/admin/Documents/01_RWTH Courses/03_ WiSe21/CIE/Project A/Data/Up/Gregori/gait01_gregori_up1 2021-11-04 16-00-48/Gyroscope.csv")

# %%
gregori_up_1.head(500)
# Out:
#      Time (s)  Gyroscope x (rad/s)  Gyroscope y (rad/s)  Gyroscope z (rad/s)
# 0    0.030878            -0.142071            -0.024309            -0.048757
# 1    0.033394            -0.139941            -0.014724            -0.058342
# 2    0.035910            -0.135681            -0.012594            -0.057277
# 3    0.038425            -0.134616            -0.007269            -0.060472
# 4    0.040941            -0.131421             0.001251            -0.063667
# ..        ...                  ...                  ...                  ...
# 495  1.285412            -0.090951            -0.125484            -0.072187
# 496  1.287927            -0.087756            -0.113769            -0.071122
# 497  1.290443            -0.084561            -0.104184            -0.065797
# 498  1.292959            -0.079236            -0.089274            -0.063667
# 499  1.295474            -0.074976            -0.074364            -0.061537
#
# [500 rows x 4 columns]

# %%
gregori_up_1.plot.scatter(x="Time (s)",y="Gyroscope z (rad/s)")
# Out:
# <AxesSubplot:xlabel='Time (s)', ylabel='Gyroscope z (rad/s)'>

# %%
gregori_up_1.plot.scatter(x="Time (s)",y="Gyroscope y (rad/s)")
# Out:
# <AxesSubplot:xlabel='Time (s)', ylabel='Gyroscope y (rad/s)'>

# %%
gregori_up_1.plot.scatter(x="Time (s)",y="Gyroscope x (rad/s)")
# Out:
# <AxesSubplot:xlabel='Time (s)', ylabel='Gyroscope x (rad/s)'>
